# %%
def display_full_name(first_name, last_name):
    print(f'Hello {first_name} {last_name}, nice to meet you!')
display_full_name("Ajala", "Timilehin")
# Out:
# Hello Ajala Timilehin, nice to meet you!
